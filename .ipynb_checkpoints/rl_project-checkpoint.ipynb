# %%
import numpy as np
import matplotlib.pyplot as plt
import os
print(os.path.abspath("rl_project.ipynb"))
# Out:
# C:\Users\baugh\thermostat\rl_project.ipynb

# %%
T = 50
T_env = 50
heater_power = 1
alpha = 0.1
beta = 0.05

temps = []
for t in range(200):
    T = T + alpha*heater_power - beta*(T - T_env)
    temps.append(T)

plt.plot(temps)
plt.xlabel("Time Step")
plt.ylabel("Temperature")
plt.title("Temperature Simulation")
plt.show()

# %%
target_temp = 70
actions = [0, 0.5, 1]
reward = -abs(T - target_temp)

# %%
class TempEnv:
    def __init__(self, target=25):
        self.T_env = 20
        self.alpha = 0.6
        self.beta = 0.1
        self.actions = [-1, -0.5, 0, 0.5, 1]
        self.target = target
        self.reset()

    def reset(self):
        self.T = np.random.uniform(0,49)
        return self.T

    def step(self, action):
        power = self.actions[action]
        noise = np.random.normal(0, 0.2)
        self.T = self.T + self.alpha*power - self.beta*(self.T - self.T_env) + noise

        reward = -abs(self.T - self.target) - 0.1*abs(power)

        done = False

        return self.T, reward, done

# %%
env = TempEnv(target=25)
state = env.reset()
temps = []

for _ in range(50):
    action = 4
    state, reward, done = env.step(action)
    temps.append(state)

plt.plot(temps)
plt.xlabel("Time step")
plt.ylabel("Temperature")
plt.show()

# %%
def get_state(temp):
    return int(np.clip(round(temp*2), 0, 99))

env = TempEnv()
num_states = 100
num_actions = 5
Q = np.zeros((num_states, num_actions))

alpha = 0.1
gamma = 0.95
epsilon = 1.0
epsilon_min = 0.05
epsilon_decay = 0.995

episodes = 2000
max_steps = 200
episode_rewards = []
episode_lengths = []

for episode in range(episodes):
    state = get_state(env.reset())
    total_reward = 0

    for t in range(max_steps):
        if np.random.rand() < epsilon:
            action = np.random.randint(num_actions)
        else:
            action = np.argmax(Q[state])

        next_temp, reward, done = env.step(action)
        next_state = get_state(next_temp)

        if done:
            target = reward
        else:
            target = reward + gamma * np.max(Q[next_state])

        Q[state, action] = Q[state, action] + alpha*(target - Q[state, action])
        state = next_state
        total_reward += reward

        if done:
            break

    epsilon = max(epsilon_min, epsilon*epsilon_decay)

    episode_rewards.append(total_reward)
    episode_lengths.append(t+1)
    
    if episode % 50 == 0:
        avg_recent = np.mean(episode_rewards[-50:]) if len(episode_rewards) >= 50 else np.mean(episode_rewards)
        print("Episode:", episode, "Reward:", total_reward, "Avg(Last 50):", avg_recent, "Epsilon", epsilon)
print("Training Complete")

temps = []
powers = []
rewards = []

state = get_state(env.reset())

for t in range(max_steps):
    action = np.argmax(Q[state])
    temp, reward, done = env.step(action)
    power = env.actions[action]

    if t % 10 == 0:
        print("Step:", t, "Temp:", temp, "Power:", power)
    temps.append(temp)
    powers.append(power)
    rewards.append(reward)

    state = get_state(temp)

    if done:
        break

plt.figure()
plt.plot(temps)
plt.axhline(env.target)
plt.title("Temperature Control")
plt.xlabel("Time")
plt.ylabel("Temperature")
plt.show()

plt.figure()
plt.plot(powers)
plt.title("Heater Power Usage")
plt.xlabel("Time")
plt.ylabel("Power")
plt.show()

plt.figure()
plt.plot(episode_rewards)
plt.xlabel("Episode")
plt.ylabel("Total Reward")
plt.title("Learning Curve")
plt.show()

window = 100
if len(episode_rewards) >= window:
    smoothed_rewards = np.convolve(episode_rewards, np.ones(window)/window, mode='valid')
    plt.figure()
    plt.plot(smoothed_rewards)
    plt.xlabel("Episode")
    plt.ylabel("Smoothed Reward")
    plt.title("Smoothed Learning Curve")
    plt.show()

plt.figure()
plt.plot(episode_lengths)
plt.xlabel("Episode")
plt.ylabel("Steps Survived / Used")
plt.title("Episode Lengths")
plt.show
# Out:
# Episode: 0 Reward: -1119.653827910679 Avg(Last 50): -1119.653827910679 Epsilon 0.995
# Episode: 50 Reward: -871.6212092937016 Avg(Last 50): -917.8976193184045 Epsilon 0.7744209942832988
# Episode: 100 Reward: -580.9713927481171 Avg(Last 50): -746.7127366925226 Epsilon 0.6027415843082742
# Episode: 150 Reward: -334.2942818025322 Avg(Last 50): -550.5661460172761 Epsilon 0.46912134373457726
# Episode: 200 Reward: -316.81533748160643 Avg(Last 50): -404.20125582217804 Epsilon 0.36512303261753626
# Episode: 250 Reward: -231.16002244381497 Avg(Last 50): -335.6521139201046 Epsilon 0.28417984116121187
# Episode: 300 Reward: -256.20746556357597 Avg(Last 50): -261.20947735156454 Epsilon 0.2211807388415433
# Episode: 350 Reward: -170.05544302412352 Avg(Last 50): -231.19581944533354 Epsilon 0.17214774642209296
# Episode: 400 Reward: -143.3905748923262 Avg(Last 50): -187.570873184417 Epsilon 0.13398475271138335
# Episode: 450 Reward: -206.62691475476714 Avg(Last 50): -190.773235264284 Epsilon 0.1042820154910064
# Episode: 500 Reward: -138.21956815454098 Avg(Last 50): -206.5970093348598 Epsilon 0.0811640021330769
# Episode: 550 Reward: -90.61301885990113 Avg(Last 50): -185.84136207580315 Epsilon 0.06317096204211972
# Episode: 600 Reward: -157.68582675226898 Avg(Last 50): -153.92612225166587 Epsilon 0.05
# Episode: 650 Reward: -116.06212742139908 Avg(Last 50): -178.2684162184492 Epsilon 0.05
# Episode: 700 Reward: -384.0624580002997 Avg(Last 50): -181.06192022988475 Epsilon 0.05
# Episode: 750 Reward: -69.31817047121682 Avg(Last 50): -186.48123765100783 Epsilon 0.05
# Episode: 800 Reward: -87.80554595204339 Avg(Last 50): -151.1823948679358 Epsilon 0.05
# Episode: 850 Reward: -240.14714012482142 Avg(Last 50): -168.61391236591408 Epsilon 0.05
# Episode: 900 Reward: -108.13902604142426 Avg(Last 50): -155.73379787853898 Epsilon 0.05
# Episode: 950 Reward: -164.72853164260485 Avg(Last 50): -169.41521503195946 Epsilon 0.05
# Episode: 1000 Reward: -95.3986348734483 Avg(Last 50): -147.53176933481197 Epsilon 0.05
# Episode: 1050 Reward: -163.09905834629566 Avg(Last 50): -160.84132464820215 Epsilon 0.05
